# %% [markdown]
# # Web Scraping Goodreads: Exploring the World of Books
#
# Welcome to this web scraping project where extract data from [Goodreads](https://www.goodreads.com/). Welcome into the world of books, data, and insights. If you're a book lover like me, you're in for a treat! And if you're not, well, I believe this project might just inspire you to delve into the captivating realm of literature.
#
# In this project, we'll be harnessing the power of web scraping to extract a wealth of information from Goodreads, a treasure trove of book-related data. From book titles and authors to ratings, and more, Goodreads offers a vast reservoir of knowledge waiting to be explored.
#
# This introductory guide will walk you through the process of setting up your environment, sending HTTP requests, and navigating the structure of web pages to gather data. It's a journey that promises exciting possibilities for data analysis and uncovering hidden insights about the world of books.
#
# So, let's dive in and start exploring the fascinating world of literature through the lens of data! Get ready to scrape, analyze, and discover the stories that await us.

# %%
#imports necessary libraries (Pandas, requests, BeautifulSoup) for web scraping and data manipulation.

import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# Fetch the HTML content of the "self-help" bookshelf on Goodreads.
base_url = "https://www.goodreads.com/shelf/show/self-help"
response = requests.get(base_url).text

# %%
soup = BeautifulSoup(response, "html.parser")

# %%
# Find and extract the total number of items
total_items_info = soup.find("div", class_="mediumText").get_text().strip()
total_items = int(total_items_info.split()[-1].replace(',', ''))

# %%
# Set the number of items displayed per page and calculate the number of pages
items_per_page = 50  # Adjust based on the actual number of items per page
total_pages = (total_items + items_per_page - 1) // items_per_page

# Limit the number of pages to scrape (e.g., the first 50 pages)
max_pages_to_scrape = 200

# %%
# Initialize lists to store data
title = []
url_list = []
authors = []
avg_ratings = []
rating = []
year = []

# %%
# Iterate through the specified number of pages
for page in range(1, min(max_pages_to_scrape, total_pages) + 1):
    url = f"{base_url}?page={page}"
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")
    book_elements = soup.find_all("div", "elementList")
    
    for book_element in book_elements:
        # Use try-except block to handle potential NoneType errors
        try:
            book_title = book_element.find("a", "bookTitle").text
            book_url = "https://www.goodreads.com" + book_element.find("a", "bookTitle").get("href")
            author = book_element.find("a", "authorName").text
            rating_text = book_element.find("span", "greyText smallText").text.split()
            avg_rating = rating_text[2]
            ratings = rating_text[4]
            published_year = rating_text[-1] if len(rating_text) == 9 else ""
    
            # Append data to lists
            title.append(book_title)
            url_list.append(book_url)
            authors.append(author)
            avg_ratings.append(avg_rating)
            rating.append(ratings)
            year.append(published_year)
        except AttributeError:
            # Handle the case where an element is not found
            print(f"Skipping a book on page {page} due to missing data.")
# Out:
# Skipping a book on page 1 due to missing data.
# Skipping a book on page 1 due to missing data.
# Skipping a book on page 2 due to missing data.
# Skipping a book on page 2 due to missing data.
# Skipping a book on page 3 due to missing data.
# Skipping a book on page 3 due to missing data.
# Skipping a book on page 4 due to missing data.
# Skipping a book on page 4 due to missing data.
# Skipping a book on page 5 due to missing data.
# Skipping a book on page 5 due to missing data.
# Skipping a book on page 6 due to missing data.
# Skipping a book on page 6 due to missing data.
# Skipping a book on page 7 due to missing data.
# Skipping a book on page 7 due to missing data.
# Skipping a book on page 8 due to missing data.
# Skipping a book on page 8 due to missing data.
# Skipping a book on page 9 due to missing data.
# Skipping a book on page 9 due to missing data.
# Skipping a book on page 10 due to missing data.
# Skipping a book on page 10 due to missing data.
# Skipping a book on page 11 due to missing data.
# Skipping a book on page 11 due to missing data.
# Skipping a book on page 12 due to missing data.
# Skipping a book on page 12 due to missing data.
# Skipping a book on page 13 due to missing data.
# Skipping a book on page 13 due to missing data.
# Skipping a book on page 14 due to missing data.
# Skipping a book on page 14 due to missing data.
# Skipping a book on page 15 due to missing data.
# Skipping a book on page 15 due to missing data.
# Skipping a book on page 16 due to missing data.
# Skipping a book on page 16 due to missing data.
# Skipping a book on page 17 due to missing data.
# Skipping a book on page 17 due to missing data.
# Skipping a book on page 18 due to missing data.
# Skipping a book on page 18 due to missing data.
# Skipping a book on page 19 due to missing data.
# Skipping a book on page 19 due to missing data.
# Skipping a book on page 20 due to missing data.
# Skipping a book on page 20 due to missing data.
# Skipping a book on page 21 due to missing data.
# Skipping a book on page 21 due to missing data.
# Skipping a book on page 22 due to missing data.
# Skipping a book on page 22 due to missing data.
# Skipping a book on page 23 due to missing data.
# Skipping a book on page 23 due to missing data.
# Skipping a book on page 24 due to missing data.
# Skipping a book on page 24 due to missing data.
# Skipping a book on page 25 due to missing data.
# Skipping a book on page 25 due to missing data.
# Skipping a book on page 26 due to missing data.
# Skipping a book on page 26 due to missing data.
# Skipping a book on page 27 due to missing data.
# Skipping a book on page 27 due to missing data.
# Skipping a book on page 28 due to missing data.
# Skipping a book on page 28 due to missing data.
# Skipping a book on page 29 due to missing data.
# Skipping a book on page 29 due to missing data.
# Skipping a book on page 30 due to missing data.
# Skipping a book on page 30 due to missing data.
# Skipping a book on page 31 due to missing data.
# Skipping a book on page 31 due to missing data.
# Skipping a book on page 32 due to missing data.
# Skipping a book on page 32 due to missing data.
# Skipping a book on page 33 due to missing data.
# Skipping a book on page 33 due to missing data.
# Skipping a book on page 34 due to missing data.
# Skipping a book on page 34 due to missing data.
# Skipping a book on page 35 due to missing data.
# Skipping a book on page 35 due to missing data.
# Skipping a book on page 36 due to missing data.
# Skipping a book on page 36 due to missing data.
# Skipping a book on page 37 due to missing data.
# Skipping a book on page 37 due to missing data.
# Skipping a book on page 38 due to missing data.
# Skipping a book on page 38 due to missing data.
# Skipping a book on page 39 due to missing data.
# Skipping a book on page 39 due to missing data.
# Skipping a book on page 40 due to missing data.
# Skipping a book on page 40 due to missing data.
# Skipping a book on page 41 due to missing data.
# Skipping a book on page 41 due to missing data.
# Skipping a book on page 42 due to missing data.
# Skipping a book on page 42 due to missing data.
# Skipping a book on page 43 due to missing data.
# Skipping a book on page 43 due to missing data.
# Skipping a book on page 44 due to missing data.
# Skipping a book on page 44 due to missing data.
# Skipping a book on page 45 due to missing data.
# Skipping a book on page 45 due to missing data.
# Skipping a book on page 46 due to missing data.
# Skipping a book on page 46 due to missing data.
# Skipping a book on page 47 due to missing data.
# Skipping a book on page 47 due to missing data.
# Skipping a book on page 48 due to missing data.
# Skipping a book on page 48 due to missing data.
# Skipping a book on page 49 due to missing data.
# Skipping a book on page 49 due to missing data.
# Skipping a book on page 50 due to missing data.
# Skipping a book on page 50 due to missing data.
# Skipping a book on page 51 due to missing data.
# Skipping a book on page 51 due to missing data.
# Skipping a book on page 52 due to missing data.
# Skipping a book on page 52 due to missing data.
# Skipping a book on page 53 due to missing data.
# Skipping a book on page 53 due to missing data.
# Skipping a book on page 54 due to missing data.
# Skipping a book on page 54 due to missing data.
# Skipping a book on page 55 due to missing data.
# Skipping a book on page 55 due to missing data.
# Skipping a book on page 56 due to missing data.
# Skipping a book on page 56 due to missing data.
# Skipping a book on page 57 due to missing data.
# Skipping a book on page 57 due to missing data.
# Skipping a book on page 58 due to missing data.
# Skipping a book on page 58 due to missing data.
# Skipping a book on page 59 due to missing data.
# Skipping a book on page 59 due to missing data.
# Skipping a book on page 60 due to missing data.
# Skipping a book on page 60 due to missing data.
# Skipping a book on page 61 due to missing data.
# Skipping a book on page 61 due to missing data.
# Skipping a book on page 62 due to missing data.
# Skipping a book on page 62 due to missing data.
# Skipping a book on page 63 due to missing data.
# Skipping a book on page 63 due to missing data.
# Skipping a book on page 64 due to missing data.
# Skipping a book on page 64 due to missing data.
# Skipping a book on page 65 due to missing data.
# Skipping a book on page 65 due to missing data.
# Skipping a book on page 66 due to missing data.
# Skipping a book on page 66 due to missing data.
# Skipping a book on page 67 due to missing data.
# Skipping a book on page 67 due to missing data.
# Skipping a book on page 68 due to missing data.
# Skipping a book on page 68 due to missing data.
# Skipping a book on page 69 due to missing data.
# Skipping a book on page 69 due to missing data.
# Skipping a book on page 70 due to missing data.
# Skipping a book on page 70 due to missing data.
# Skipping a book on page 71 due to missing data.
# Skipping a book on page 71 due to missing data.
# Skipping a book on page 72 due to missing data.
# Skipping a book on page 72 due to missing data.
# Skipping a book on page 73 due to missing data.
# Skipping a book on page 73 due to missing data.
# Skipping a book on page 74 due to missing data.
# Skipping a book on page 74 due to missing data.
# Skipping a book on page 75 due to missing data.
# Skipping a book on page 75 due to missing data.
# Skipping a book on page 76 due to missing data.
# Skipping a book on page 76 due to missing data.
# Skipping a book on page 77 due to missing data.
# Skipping a book on page 77 due to missing data.
# Skipping a book on page 78 due to missing data.
# Skipping a book on page 78 due to missing data.
# Skipping a book on page 79 due to missing data.
# Skipping a book on page 79 due to missing data.
# Skipping a book on page 80 due to missing data.
# Skipping a book on page 80 due to missing data.
# Skipping a book on page 81 due to missing data.
# Skipping a book on page 81 due to missing data.
# Skipping a book on page 82 due to missing data.
# Skipping a book on page 82 due to missing data.
# Skipping a book on page 83 due to missing data.
# Skipping a book on page 83 due to missing data.
# Skipping a book on page 84 due to missing data.
# Skipping a book on page 84 due to missing data.
# Skipping a book on page 85 due to missing data.
# Skipping a book on page 85 due to missing data.
# Skipping a book on page 86 due to missing data.
# Skipping a book on page 86 due to missing data.
# Skipping a book on page 87 due to missing data.
# Skipping a book on page 87 due to missing data.
# Skipping a book on page 88 due to missing data.
# Skipping a book on page 88 due to missing data.
# Skipping a book on page 89 due to missing data.
# Skipping a book on page 89 due to missing data.
# Skipping a book on page 90 due to missing data.
# Skipping a book on page 90 due to missing data.
# Skipping a book on page 91 due to missing data.
# Skipping a book on page 91 due to missing data.
# Skipping a book on page 92 due to missing data.
# Skipping a book on page 92 due to missing data.
# Skipping a book on page 93 due to missing data.
# Skipping a book on page 93 due to missing data.
# Skipping a book on page 94 due to missing data.
# Skipping a book on page 94 due to missing data.
# Skipping a book on page 95 due to missing data.
# Skipping a book on page 95 due to missing data.
# Skipping a book on page 96 due to missing data.
# Skipping a book on page 96 due to missing data.
# Skipping a book on page 97 due to missing data.
# Skipping a book on page 97 due to missing data.
# Skipping a book on page 98 due to missing data.
# Skipping a book on page 98 due to missing data.
# Skipping a book on page 99 due to missing data.
# Skipping a book on page 99 due to missing data.
# Skipping a book on page 100 due to missing data.
# Skipping a book on page 100 due to missing data.
# Skipping a book on page 101 due to missing data.
# Skipping a book on page 101 due to missing data.
# Skipping a book on page 102 due to missing data.
# Skipping a book on page 102 due to missing data.
# Skipping a book on page 103 due to missing data.
# Skipping a book on page 103 due to missing data.
# Skipping a book on page 104 due to missing data.
# Skipping a book on page 104 due to missing data.
# Skipping a book on page 105 due to missing data.
# Skipping a book on page 105 due to missing data.
# Skipping a book on page 106 due to missing data.
# Skipping a book on page 106 due to missing data.
# Skipping a book on page 107 due to missing data.
# Skipping a book on page 107 due to missing data.
# Skipping a book on page 108 due to missing data.
# Skipping a book on page 108 due to missing data.
# Skipping a book on page 109 due to missing data.
# Skipping a book on page 109 due to missing data.
# Skipping a book on page 110 due to missing data.
# Skipping a book on page 110 due to missing data.
# Skipping a book on page 111 due to missing data.
# Skipping a book on page 111 due to missing data.
# Skipping a book on page 112 due to missing data.
# Skipping a book on page 112 due to missing data.
# Skipping a book on page 113 due to missing data.
# Skipping a book on page 113 due to missing data.
# Skipping a book on page 114 due to missing data.
# Skipping a book on page 114 due to missing data.
# Skipping a book on page 115 due to missing data.
# Skipping a book on page 115 due to missing data.
# Skipping a book on page 116 due to missing data.
# Skipping a book on page 116 due to missing data.
# Skipping a book on page 117 due to missing data.
# Skipping a book on page 117 due to missing data.
# Skipping a book on page 118 due to missing data.
# Skipping a book on page 118 due to missing data.
# Skipping a book on page 119 due to missing data.
# Skipping a book on page 119 due to missing data.
# Skipping a book on page 120 due to missing data.
# Skipping a book on page 120 due to missing data.
# Skipping a book on page 121 due to missing data.
# Skipping a book on page 121 due to missing data.
# Skipping a book on page 122 due to missing data.
# Skipping a book on page 122 due to missing data.
# Skipping a book on page 123 due to missing data.
# Skipping a book on page 123 due to missing data.
# Skipping a book on page 124 due to missing data.
# Skipping a book on page 124 due to missing data.
# Skipping a book on page 125 due to missing data.
# Skipping a book on page 125 due to missing data.
# Skipping a book on page 126 due to missing data.
# Skipping a book on page 126 due to missing data.
# Skipping a book on page 127 due to missing data.
# Skipping a book on page 127 due to missing data.
# Skipping a book on page 128 due to missing data.
# Skipping a book on page 128 due to missing data.
# Skipping a book on page 129 due to missing data.
# Skipping a book on page 129 due to missing data.
# Skipping a book on page 130 due to missing data.
# Skipping a book on page 130 due to missing data.
# Skipping a book on page 131 due to missing data.
# Skipping a book on page 131 due to missing data.
# Skipping a book on page 132 due to missing data.
# Skipping a book on page 132 due to missing data.
# Skipping a book on page 133 due to missing data.
# Skipping a book on page 133 due to missing data.
# Skipping a book on page 134 due to missing data.
# Skipping a book on page 134 due to missing data.
# Skipping a book on page 135 due to missing data.
# Skipping a book on page 135 due to missing data.
# Skipping a book on page 136 due to missing data.
# Skipping a book on page 136 due to missing data.
# Skipping a book on page 137 due to missing data.
# Skipping a book on page 137 due to missing data.
# Skipping a book on page 138 due to missing data.
# Skipping a book on page 138 due to missing data.
# Skipping a book on page 139 due to missing data.
# Skipping a book on page 139 due to missing data.
# Skipping a book on page 140 due to missing data.
# Skipping a book on page 140 due to missing data.
# Skipping a book on page 141 due to missing data.
# Skipping a book on page 141 due to missing data.
# Skipping a book on page 142 due to missing data.
# Skipping a book on page 142 due to missing data.
# Skipping a book on page 143 due to missing data.
# Skipping a book on page 143 due to missing data.
# Skipping a book on page 144 due to missing data.
# Skipping a book on page 144 due to missing data.
# Skipping a book on page 145 due to missing data.
# Skipping a book on page 145 due to missing data.
# Skipping a book on page 146 due to missing data.
# Skipping a book on page 146 due to missing data.
# Skipping a book on page 147 due to missing data.
# Skipping a book on page 147 due to missing data.
# Skipping a book on page 148 due to missing data.
# Skipping a book on page 148 due to missing data.
# Skipping a book on page 149 due to missing data.
# Skipping a book on page 149 due to missing data.
# Skipping a book on page 150 due to missing data.
# Skipping a book on page 150 due to missing data.
# Skipping a book on page 151 due to missing data.
# Skipping a book on page 151 due to missing data.
# Skipping a book on page 152 due to missing data.
# Skipping a book on page 152 due to missing data.
# Skipping a book on page 153 due to missing data.
# Skipping a book on page 153 due to missing data.
# Skipping a book on page 154 due to missing data.
# Skipping a book on page 154 due to missing data.
# Skipping a book on page 155 due to missing data.
# Skipping a book on page 155 due to missing data.
# Skipping a book on page 156 due to missing data.
# Skipping a book on page 156 due to missing data.
# Skipping a book on page 157 due to missing data.
# Skipping a book on page 157 due to missing data.
# Skipping a book on page 158 due to missing data.
# Skipping a book on page 158 due to missing data.
# Skipping a book on page 159 due to missing data.
# Skipping a book on page 159 due to missing data.
# Skipping a book on page 160 due to missing data.
# Skipping a book on page 160 due to missing data.
# Skipping a book on page 161 due to missing data.
# Skipping a book on page 161 due to missing data.
# Skipping a book on page 162 due to missing data.
# Skipping a book on page 162 due to missing data.
# Skipping a book on page 163 due to missing data.
# Skipping a book on page 163 due to missing data.
# Skipping a book on page 164 due to missing data.
# Skipping a book on page 164 due to missing data.
# Skipping a book on page 165 due to missing data.
# Skipping a book on page 165 due to missing data.
# Skipping a book on page 166 due to missing data.
# Skipping a book on page 166 due to missing data.
# Skipping a book on page 167 due to missing data.
# Skipping a book on page 167 due to missing data.
# Skipping a book on page 168 due to missing data.
# Skipping a book on page 168 due to missing data.
# Skipping a book on page 169 due to missing data.
# Skipping a book on page 169 due to missing data.
# Skipping a book on page 170 due to missing data.
# Skipping a book on page 170 due to missing data.
# Skipping a book on page 171 due to missing data.
# Skipping a book on page 171 due to missing data.
# Skipping a book on page 172 due to missing data.
# Skipping a book on page 172 due to missing data.
# Skipping a book on page 173 due to missing data.
# Skipping a book on page 173 due to missing data.
# Skipping a book on page 174 due to missing data.
# Skipping a book on page 174 due to missing data.
# Skipping a book on page 175 due to missing data.
# Skipping a book on page 175 due to missing data.
# Skipping a book on page 176 due to missing data.
# Skipping a book on page 176 due to missing data.
# Skipping a book on page 177 due to missing data.
# Skipping a book on page 177 due to missing data.
# Skipping a book on page 178 due to missing data.
# Skipping a book on page 178 due to missing data.
# Skipping a book on page 179 due to missing data.
# Skipping a book on page 179 due to missing data.
# Skipping a book on page 180 due to missing data.
# Skipping a book on page 180 due to missing data.
# Skipping a book on page 181 due to missing data.
# Skipping a book on page 181 due to missing data.
# Skipping a book on page 182 due to missing data.
# Skipping a book on page 182 due to missing data.
# Skipping a book on page 183 due to missing data.
# Skipping a book on page 183 due to missing data.
# Skipping a book on page 184 due to missing data.
# Skipping a book on page 184 due to missing data.
# Skipping a book on page 185 due to missing data.
# Skipping a book on page 185 due to missing data.
# Skipping a book on page 186 due to missing data.
# Skipping a book on page 186 due to missing data.
# Skipping a book on page 187 due to missing data.
# Skipping a book on page 187 due to missing data.
# Skipping a book on page 188 due to missing data.
# Skipping a book on page 188 due to missing data.
# Skipping a book on page 189 due to missing data.
# Skipping a book on page 189 due to missing data.
# Skipping a book on page 190 due to missing data.
# Skipping a book on page 190 due to missing data.
# Skipping a book on page 191 due to missing data.
# Skipping a book on page 191 due to missing data.
# Skipping a book on page 192 due to missing data.
# Skipping a book on page 192 due to missing data.
# Skipping a book on page 193 due to missing data.
# Skipping a book on page 193 due to missing data.
# Skipping a book on page 194 due to missing data.
# Skipping a book on page 194 due to missing data.
# Skipping a book on page 195 due to missing data.
# Skipping a book on page 195 due to missing data.
# Skipping a book on page 196 due to missing data.
# Skipping a book on page 196 due to missing data.
# Skipping a book on page 197 due to missing data.
# Skipping a book on page 197 due to missing data.
# Skipping a book on page 198 due to missing data.
# Skipping a book on page 198 due to missing data.
# Skipping a book on page 199 due to missing data.
# Skipping a book on page 199 due to missing data.
# Skipping a book on page 200 due to missing data.
# Skipping a book on page 200 due to missing data.

# %%
# Create a DataFrame
good_reads = pd.DataFrame({
    "Title": title,
    "URL": url_list,
    "Authors": authors,
    "Avg Ratings": avg_ratings,
    "Rating": rating,
    "Published_year": year
})

# %%
good_reads.head()
# Out:
#                                                Title  \
# 0  Atomic Habits: An Easy & Proven Way to Build G...
# 1  The Subtle Art of Not Giving a F*ck: A Counter...
# 2  How to Win Friends and Influence People (Paper...
# 3  The 7 Habits of Highly Effective People: Power...
# 4  The Power of Habit: Why We Do What We Do in Li...
#
#                                                  URL           Authors  \
# 0  https://www.goodreads.com/book/show/40121378-a...       James Clear
# 1  https://www.goodreads.com/book/show/28257707-t...       Mark Manson
# 2  https://www.goodreads.com/book/show/4865.How_t...     Dale Carnegie
# 3  https://www.goodreads.com/book/show/36072.The_...  Stephen R. Covey
# 4  https://www.goodreads.com/book/show/12609433-t...    Charles Duhigg
#
#   Avg Ratings     Rating Published_year
# 0        4.37    698,883
# 1        3.90  1,002,966           2017
# 2        4.22    916,840           1936
# 3        4.15    708,544           1988
# 4        4.13    483,249           2012

# %%
len(good_reads)
# Out:
# 10000

# %%
good_reads.to_csv("goodreads.csv", index=False)
